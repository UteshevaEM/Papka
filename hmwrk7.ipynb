# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
newsgroups_train.target[:10]
# Out:
# array([ 7,  4,  4,  1, 14, 16, 13,  3,  2,  4])

# %%
n = 0
print('Topic = {0}\n'.format(newsgroups_train.target_names[newsgroups_train.target[n]]))
print(newsgroups_train.data[n])
# Out:
# Topic = rec.autos
#
# I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

vectorizer = CountVectorizer(lowercase=True, stop_words=ENGLISH_STOP_WORDS,
                             analyzer='word', binary=True, min_df=14, max_df=.04)
vectorizer.fit(newsgroups_train.data)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.04, max_features=None, min_df=14,
#                 ngram_range=(1, 1), preprocessor=None,
#                 stop_words=frozenset({'a', 'about', 'above', 'across', 'after',
#                                       'afterwards', 'again', 'against', 'all',
#                                       'almost', 'alone', 'along', 'already',
#                                       'also', 'although', 'always', 'am',
#                                       'among', 'amongst', 'amoungst', 'amount',
#                                       'an', 'and', 'another', 'any', 'anyhow',
#                                       'anyone', 'anything', 'anyway',
#                                       'anywhere', ...}),
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
len(vectorizer.vocabulary_)
# Out:
# 7891

# %%
vectorizer.vocabulary_
# Out:
# {'wondering': 7794,
#  'car': 1398,
#  'saw': 6302,
#  'door': 2473,
#  'sports': 6751,
#  'looked': 4353,
#  'late': 4169,
#  'early': 2555,
#  'doors': 2474,
#  'small': 6621,
#  'addition': 563,
#  'bumper': 1312,
#  'separate': 6430,
#  'rest': 6076,
#  'body': 1186,
#  'model': 4689,
#  'engine': 2686,
#  'specs': 6719,
#  'production': 5617,
#  'history': 3529,
#  'info': 3788,
#  'fair': 2914,
#  'brave': 1249,
#  'souls': 6679,
#  'upgraded': 7478,
#  'si': 6533,
#  'clock': 1617,
#  'oscillator': 5099,
#  'shared': 6484,
#  'experiences': 2842,
#  'poll': 5440,
#  'brief': 1262,
#  'message': 4583,
#  'procedure': 5600,
#  'speed': 6725,
#  'cpu': 2017,
#  'rated': 5828,
#  'add': 560,
#  'cards': 1402,
#  'adapters': 557,
#  'heat': 3480,
#  'hour': 3586,
#  'usage': 7489,
#  'floppy': 3066,
#  'disk': 2410,
#  'functionality': 3183,
#  '800': 418,
#  'floppies': 3065,
#  'especially': 2738,
#  'requested': 6033,
#  'days': 2137,
#  'network': 4873,
#  'knowledge': 4121,
#  'base': 1038,
#  'upgrade': 7477,
#  'haven': 3460,
#  'answered': 749,
#  'folks': 3080,
#  'mac': 4405,
#  'plus': 5416,
#  'finally': 3009,
#  'gave': 3222,
#  'ghost': 3267,
#  'weekend': 7714,
#  'starting': 6794,
#  '512k': 350,
#  '1985': 155,
#  'market': 4479,
#  'machine': 4406,
#  'sooner': 6672,
#  'intended': 3859,
#  'picking': 5340,
#  'powerbook': 5491,
#  '160': 92,
#  '180': 110,
#  'bunch': 1313,
#  'questions': 5767,
#  'hopefully': 3568,
#  'somebody': 6664,
#  'answer': 748,
#  'anybody': 755,
#  'dirt': 2374,
#  'round': 6208,
#  'expected': 2835,
#  'supposed': 6977,
#  'summer': 6960,
#  'anymore': 756,
#  'access': 504,
#  'rumors': 6234,
#  'price': 5563,
#  'drops': 2517,
#  'ones': 5031,
#  'duo': 2538,
#  'went': 7723,
#  'recently': 5882,
#  'impression': 3708,
#  'display': 2416,
#  'swing': 7016,
#  '120': 44,
#  'feel': 2973,
#  'looks': 4354,
#  'store': 6854,
#  'wow': 7822,
#  'opinions': 5055,
#  'worth': 7815,
#  'taking': 7050,
#  'size': 6585,
#  'money': 4712,
#  'hit': 3530,
#  'active': 543,
#  'realize': 5860,
#  'subjective': 6911,
#  'played': 5399,
#  'machines': 4407,
#  'computer': 1776,
#  'figured': 2996,
#  'uses': 7495,
#  'daily': 2104,
#  'prove': 5686,
#  'helpful': 3497,
#  'perform': 5280,
#  'advance': 592,
#  'summary': 6959,
#  'news': 4880,
#  'reading': 5852,
#  'premium': 5532,
#  'finals': 3010,
#  'corner': 1967,
#  'tom': 7240,
#  'ecn': 2574,
#  'purdue': 5728,
#  'electrical': 2625,
#  'engineering': 2689,
#  'address': 567,
#  'phone': 5324,
#  'chip': 1534,
#  'article': 852,
#  'std': 6815,
#  'baker': 1013,
#  'understanding': 7436,
#  'errors': 2728,
#  'basically': 1042,
#  'known': 4123,
#  'bugs': 1299,
#  'warning': 7671,
#  'checked': 1514,
#  'values': 7529,
#  'aren': 817,
#  'till': 7213,
#  'launch': 4177,
#  'fix': 3036,
#  'code': 1647,
#  'possibly': 5472,
#  'introduce': 3901,
#  'crew': 2041,
#  'ok': 5020,
#  '213': 193,
#  'ignore': 3657,
#  'term': 7127,
#  'defined': 2202,
#  'doubt': 2480,
#  'quote': 5775,
#  'allegedly': 674,
#  'presenting': 5542,
#  'argument': 825,
#  'weapons': 7707,
#  'mass': 4496,
#  'destruction': 2295,
#  'commonly': 1711,
#  'understood': 7437,
#  'switching': 7021,
#  'topics': 7255,
#  'evidently': 2777,
#  'allowed': 680,
#  'later': 4171,
#  'analysis': 718,
#  'consider': 1847,
#  'class': 1590,
#  'responded': 6068,
#  'request': 6032,
#  'treatment': 7326,
#  'couldn': 1991,
#  'thank': 7156,
#  'directly': 2370,
#  'bouncing': 1227,
#  'sean': 6362,
#  'publicly': 5710,
#  'glad': 3283,
#  'accidentally': 510,
#  'rn': 6164,
#  'instead': 3835,
#  'rm': 6163,
#  'delete': 2216,
#  'file': 2999,
#  'september': 6436,
#  'hmmm': 3538,
#  'shows': 6530,
#  'scsi': 6353,
#  'range': 5812,
#  '5mb': 363,
#  'controller': 1920,
#  'burst': 1324,
#  'note': 4923,
#  'increase': 3742,
#  'quadra': 5747,
#  'version': 7565,
#  'exist': 2820,
#  'pc': 5253,
#  'mode': 4688,
#  '16': 91,
#  'wide': 7739,
#  'fast': 2942,
#  '20mb': 187,
#  '32': 271,
#  '40mb': 308,
#  'twice': 7388,
#  'esdi': 2736,
#  'correct': 1975,
#  'reach': 5840,
#  'faster': 2943,
#  'ide': 3640,
#  '96': 449,
#  'facts': 2906,
#  'posted': 5475,
#  'newsgroup': 4881,
#  'ibm': 3631,
#  'sheet': 6495,
#  'ftp': 3173,
#  'aim': 641,
#  'stanford': 6787,
#  '36': 287,
#  '44': 319,
#  'report': 6012,
#  'compare': 1724,
#  'txt': 7394,
#  '161': 94,
#  'documented': 2457,
#  'apple': 778,
#  'maximum': 4521,
#  'slower': 6618,
#  'interface': 3876,
#  'driven': 2508,
#  'win': 7752,
#  'downloaded': 2485,
#  'icons': 3636,
#  'bmp': 1174,
#  'figure': 2995,
#  'change': 1483,
#  'appreciated': 790,
#  'thanx': 7157,
#  'board': 1178,
#  'licensing': 4273,
#  'technologies': 7097,
#  'owners': 5130,
#  'compression': 1767,
#  'technology': 7098,
#  'writing': 7832,
#  'memory': 4566,
#  'lost': 4367,
#  'reference': 5910,
#  'fault': 2950,
#  'icon': 3635,
#  'usually': 7499,
#  'mentioned': 4570,
#  'freeware': 3155,
#  'expansion': 2832,
#  'utility': 7504,
#  'dd': 2141,
#  'expand': 2829,
#  'compressed': 1766,
#  'unless': 7461,
#  'installed': 3830,
#  'product': 5616,
#  'unlikely': 7463,
#  'holes': 3546,
#  'related': 5949,
#  'fixed': 3037,
#  'sad': 6260,
#  'reluctant': 5972,
#  'buy': 1335,
#  'hey': 3508,
#  'competition': 1737,
#  '1978': 147,
#  'runs': 6238,
#  'paint': 5161,
#  'brown': 1282,
#  'orange': 5070,
#  'oil': 5018,
#  'pops': 5449,
#  '1st': 175,
#  'shop': 6514,
#  'trans': 7298,
#  'leak': 4211,
#  'sold': 6652,
#  'bike': 1123,
#  'owner': 5129,
#  'thinking': 7175,
#  'nice': 4891,
#  'stable': 6771,
#  'axis': 990,
#  'motors': 4755,
#  'tx': 7393,
#  'org': 5082,
#  'dod': 2459,
#  'yep': 7872,
#  'jew': 3997,
#  'understand': 7434,
#  'jewish': 3998,
#  'jews': 3999,
#  'abraham': 478,
#  'moses': 4737,
#  'moral': 4727,
#  'follow': 3081,
#  'mankind': 4454,
#  'decide': 2163,
#  'boundaries': 1229,
#  'fall': 2920,
#  'believed': 1093,
#  'required': 6037,
#  'ancestors': 721,
#  'modern': 4697,
#  'judaism': 4034,
#  'interpretation': 3888,
#  'lead': 4202,
#  'morality': 4728,
#  'essence': 2741,
#  'biblical': 1118,
#  'man': 4441,
#  'christian': 1546,
#  'necessarily': 4845,
#  'indicate': 3757,
#  'outside': 5117,
#  'relationship': 5954,
#  'speculate': 6722,
#  'trouble': 7353,
#  'created': 2032,
#  'image': 3672,
#  'conclusion': 1794,
#  'wants': 7664,
#  'script': 6347,
#  'foundation': 3132,
#  'mix': 4676,
#  'living': 4323,
#  'christ': 1545,
#  'jesus': 3994,
#  'recorded': 5891,
#  'followers': 3083,
#  'references': 5911,
#  'historians': 3525,
#  'revelation': 6104,
#  'aside': 861,
#  'hand': 3418,
#  'worse': 7812,
#  'attempt': 927,
#  'christianity': 1547,
#  'initially': 3801,
#  'bible': 1117,
#  'interpret': 3887,
#  'humanity': 3608,
#  'guess': 3383,
#  'faith': 2916,
#  'comes': 1687,
#  'inherent': 3796,
#  'absolute': 483,
#  'multiple': 4784,
#  'codes': 1649,
#  'founded': 3133,
#  'parent': 5189,
#  'child': 1529,
#  'swear': 7010,
#  'assume': 889,
#  'simply': 6566,
#  'told': 7236,
#  'pub': 5705,
#  'bar': 1030,
#  'children': 1531,
#  'inappropriate': 3719,
#  'happy': 3440,
#  'animals': 734,
#  'analogy': 717,
#  'hold': 3541,
#  'water': 7688,
#  'knows': 4124,
#  'type': 7395,
#  'incidentally': 3725,
#  'young': 7877,
#  'considers': 1854,
#  'gets': 3265,
#  'older': 5023,
#  'david': 2132,
#  'religion': 5969,
#  'description': 2270,
#  'external': 2883,
#  'tank': 7059,
#  'option': 5066,
#  'redesign': 5900,
#  'deleted': 2217,
#  'yo': 7875,
#  'ken': 4070,
#  'orbiter': 5073,
#  'options': 5068,
#  'today': 7232,
#  '23': 208,
#  'edition': 2587,
#  'york': 7876,
#  'reports': 6017,
#  'connor': 1838,
#  'panel': 5171,
#  'proposals': 5667,
#  'dropped': 2515,
#  'giant': 3269,
#  'fuel': 3175,
#  'tanks': 7060,
#  'space': 6692,
#  'building': 1301,
#  'station': 6804,
#  'existing': 2825,
#  'shuttle': 6532,
#  'wings': 7758,
#  'tail': 7047,
#  'removed': 5991,
#  'currently': 2080,
#  'considered': 1852,
#  'presented': 5541,
#  'meeting': 4555,
#  'yesterday': 7873,
#  'reported': 6013,
#  'low': 4377,
#  'cost': 1987,
#  'approach': 791,
#  'studied': 6898,
#  'team': 7087,
#  'teams': 7088,
#  'jsc': 4033,
#  'larc': 4158,
#  'supporting': 6974,
#  'crystal': 2064,
#  'city': 1575,
#  'site': 6578,
#  'locations': 4338,
#  'helping': 3498,
#  'respective': 6064,
#  'activities': 546,
#  'key': 4078,
#  'features': 2962,
#  'bus': 1326,
#  'developed': 2314,
#  'qualified': 5749,
#  'sts': 6894,
#  'provides': 5693,
#  'propulsion': 5673,
#  'communications': 1714,
#  'management': 4444,
#  'air': 644,
#  'force': 3096,
#  'capability': 1387,
#  'obtained': 4979,
#  'flights': 3060,
#  'solar': 6650,
#  'provide': 5690,
#  'vehicle': 7549,
#  'environment': 2711,
#  'missions': 4665,
#  'source': 6685,
#  'human': 3606,
#  'tended': 7121,
#  'opposed': 5061,
#  'achieved': 528,
#  'common': 1710,
#  'module': 4703,
#  'modified': 4701,
#  'lab': 4132,
#  'ports': 5460,
#  'added': 561,
#  'international': 3885,
#  'partners': 5211,
#  'labs': 4139,
#  '60': 368,
#  'esa': 2731,
#  'modules': 4704,
#  'permanent': 5289,
#  'presence': 5537,
#  '3rd': 302,
#  'assured': 896,
#  'return': 6095,
#  'freedom': 3152,
#  'derived': 2264,
#  'mike': 4617,
#  'alot': 684,
#  'design': 2277,
#  'love': 4373,
#  'assumes': 891,
#  'assembly': 871,
#  'computed': 1775,
#  '51': 347,
#  'inclination': 3727,
#  'orbit': 5071,
#  'build': 1300,
#  'occurs': 4994,
#  'initial': 3800,
#  'research': 6043,
#  'reached': 5841,
#  'transferred': 7302,
#  'adopted': 588,
#  'language': 4155,
#  'keeping': 4065,
#  'supply': 6971,
#  'tolerance': 7237,
#  '14': 69,
#  '2nd': 256,
#  'thermal': 7173,
#  'control': 1918,
#  'finish': 3018,
#  '24': 214,
#  'systems': 7038,
#  'exception': 2792,
#  'major': 4433,
#  'changes': 1485,
#  'reduced': 5903,
#  'prices': 5565,
#  'forsale': 3121,
#  'behalf': 1084,
#  'brother': 1279,
#  'moving': 4770,
#  'moved': 4764,
#  'offer': 5003,
#  'black': 1149,
#  'portable': 5455,
#  'purchased': 5726,
#  '12': 43,
#  'sr': 6763,
#  '1000': 17,
#  'dual': 2530,
#  'cassette': 1422,
#  'player': 5400,
#  'fm': 3074,
#  'band': 1021,
#  'graphics': 3341,
#  'tape': 7062,
#  'deck': 2169,
#  'sound': 6680,
#  'bet': 1111,
#  '80': 417,
#  '25': 223,
#  'zoom': 7889,
#  'japan': 3981,
#  'includes': 3731,
#  'accessories': 507,
#  '50': 341,
#  '1400': 71,
#  'hair': 3411,
#  'head': 3464,
#  'bag': 1010,
#  'leather': 4218,
#  'brand': 1247,
#  'speeds': 6727,
#  'extra': 2884,
#  'angle': 730,
#  'steam': 6820,
#  'dry': 2522,
#  'iron': 3939,
#  'contact': 1879,
#  'reply': 6011,
#  'included': 3730,
#  'reasonable': 5864,
#  'happened': 3435,
#  'japanese': 3982,
#  'citizens': 1573,
#  'war': 7665,
#  'ii': 3660,
#  'prepared': 5535,
#  'stick': 6835,
#  'concentration': 1783,
#  'camp': 1371,
#  'trial': 7336,
#  'short': 6517,
#  'step': 6827,
#  'nazis': 4831,
#  'originally': 5093,
#  'final': 3008,
#  'solution': 6659,
#  'partly': 5209,
#  'afford': 616,
#  'camps': 1374,
#  'caused': 1438,
#  'total': 7264,
#  'weren': 7724,
#  'generally': 3239,
#  'died': 2341,
#  'disease': 2406,
#  'certainly': 1464,
#  'tiff': 7209,
#  'works': 7804,
#  'complexity': 1755,
#  'led': 4225,
#  'programs': 5631,
#  'poor': 5445,
#  'writers': 7830,
#  'making': 4438,
#  'bizarre': 1147,
#  'files': 3002,
#  'inability': 3716,
#  'load': 4327,
#  'images': 3673,
#  'save': 6297,
#  'general': 3238,
#  'environments': 2713,
#  'despite': 2291,
#  'saying': 6303,
#  'goes': 3301,
#  'worried': 7810,
#  'abuse': 487,
#  'unnecessary': 7465,
#  'format': 3112,
#  'words': 7800,
#  'spec': 6705,
#  'page': 5156,
#  'emphasis': 2647,
#  'sort': 6675,
#  'success': 6929,
#  'designed': 2279,
#  'powerful': 5493,
#  'flexible': 3058,
#  'expense': 2838,
#  'simplicity': 6564,
#  'takes': 7049,
#  'effort': 2607,
#  'handle': 3424,
#  'specification': 6713,
#  'application': 781,
#  'complete': 1751,
#  'job': 4002,
#  'import': 3700,
#  'generating': 3243,
#  'applications': 782,
#  'deal': 2145,
#  'agrees': 634,
#  'reasoning': 5867,
#  'asking': 863,
#  'rates': 5829,
#  'single': 6572,
#  'male': 4439,
#  'drivers': 2510,
#  'paying': 5247,
#  'performance': 5281,
#  'cars': 1416,
#  'replies': 6010,
#  'received': 5876,
#  '27': 236,
#  'close': 1619,
#  '1992': 163,
#  'dodge': 2460,
#  'stealth': 6819,
#  'rt': 6224,
#  'twin': 7389,
#  'turbo': 7375,
#  'tickets': 7206,
#  'accidents': 511,
#  'house': 3588,
#  'taken': 7048,
#  'defensive': 2197,
#  'driving': 2512,
#  'abs': 480,
#  'security': 6386,
#  'alarm': 654,
#  '1500': 82,
#  '500': 342,
#  'farm': 2938,
#  'insurance': 3845,
#  'additional': 564,
#  '100': 16,
#  '000': 1,
#  'policy': 5433,
#  'standard': 6782,
#  '300': 259,
#  'bought': 1223,
#  'company': 1722,
#  'accident': 508,
#  'ticket': 7205,
#  '11': 31,
#  'quoted': 5776,
#  'helps': 3499,
#  'steve': 6831,
#  'university': 7457,
#  '45': 321,
#  'kevin': 4077,
#  'remembered': 5983,
#  'correctly': 1979,
#  'asked': 862,
#  'similar': 6557,
#  'situation': 6582,
#  'inquiry': 3816,
#  'age': 622,
#  'record': 5890,
#  'clean': 1597,
#  'illinois': 3667,
#  'turn': 7380,
#  'higher': 3514,
#  'rate': 5827,
#  'couple': 2003,
#  'friends': 3167,
#  'pay': 5246,
#  'companies': 1721,
#  'lucky': 4384,
#  'dan': 2112,
#  'mot': 4740,
#  'motorola': 4754,
#  'cellular': 1450,
#  '38': 291,
#  'usa': 7487,
#  'cc': 1444,
#  'live': 4319,
#  '89': 434,
#  'sc': 6306,
#  'claim': 1583,
#  'stop': 6849,
#  'signs': 6551,
#  'violations': 7596,
#  '18': 109,
#  'months': 4722,
#  '85': 430,
#  '55': 355,
#  'failure': 2912,
#  'clear': 1602,
#  'intersection': 3894,
#  'damn': 2110,
#  'light': 4282,
#  'yellow': 7871,
#  '35': 282,
#  'passive': 5224,
#  'liability': 4258,
#  'comprehensive': 1764,
#  'roughly': 6207,
#  '1300': 59,
#  '92': 444,
#  'lx': 4392,
#  'james': 3977,
#  'law': 4182,
#  'center': 1453,
#  'ucs': 7408,
#  'disclaimer': 2391,
#  'engineer': 2687,
#  'play': 5398,
#  'calls': 1363,
#  'bird': 1137,
#  'hell': 3491,
#  'killing': 4096,
#  'gonna': 3306,
#  '61': 373,
#  'experience': 2840,
#  'interesting': 3873,
#  'owned': 5128,
#  'toyota': 7276,
#  'gt': 3378,
#  'decided': 2164,
#  'gift': 3274,
#  'runners': 6236,
#  'porsche': 5453,
#  '1987': 157,
#  'liked': 4287,
#  'handling': 3428,
#  'appeal': 771,
#  'personal': 5299,
#  'luxury': 4391,
#  'acceleration': 495,
#  'ready': 5856,
#  'buying': 1338,
#  'impulse': 3715,
#  'agent': 626,
#  'office': 5007,
#  'happen': 3434,
#  'slight': 6610,
#  'newer': 4877,
#  'lower': 4378,
#  'risk': 6156,
#  'division': 2443,
#  'continue': 1896,
#  'account': 519,
#  'double': 2479,
#  'story': 6859,
#  'cover': 2009,
#  'sense': 6419,
#  'book': 1198,
#  'says': 6304,
#  'insure': 3846,
#  'traditional': 7290,
#  'conservative': 1846,
#  'eventually': 2771,
#  'reasons': 5868,
#  'dealer': 2146,
#  'tough': 7269,
#  'pressure': 5552,
#  'guy': 3401,
#  'room': 6197,
#  'equal': 2716,
#  'monthly': 4721,
#  'longer': 4352,
#  'concluded': 1793,
#  'probability': 5595,
#  'auto': 958,
#  'theft': 7159,
#  'entitled': 2707,
#  'opinion': 5054,
#  'dt': 2527,
#  'navy': 4829,
#  'mil': 4618,
#  'imagination': 3674,
#  'important': 3702,
#  'albert': 658,
#  'einstein': 2615,
#  'idaho': 3639,
#  '26': 232,
#  'turned': 7381,
#  'immediately': 3680,
#  'strictly': 6877,
#  'stayed': 6812,
#  '150': 81,
#  'pickup': 5342,
#  'amazing': 699,
#  'felt': 2981,
#  'responsible': 6075,
#  '21': 189,
#  'california': 1361,
#  'violation': 7595,
#  '2000': 179,
#  '28': 242,
#  'vw': 7642,
#  'san': 6279,
#  'jose': 4020,
#  'vs': 7638,
#  'v6': 7517,
#  '1986': 156,
#  'honda': 3558,
#  'mexico': 4598,
#  'town': 7273,
#  'nearby': 4840,
#  '2x': 258,
#  'robert': 6168,
#  'stack': 6772,
#  'institute': 3836,
#  'transportation': 7316,
#  'studies': 6899,
#  'univ': 7452,
#  'uci': 7406,
#  'mazda': 4523,
#  '37': 289,
#  'saturn': 6295,
#  '64': 381,
#  'st': 6769,
#  'date': 2127,
#  'license': 4270,
#  'oct': 4996,
#  'mountain': 4758,
#  'view': 7582,
#  '415': 311,
#  '1200': 45,
#  'knock': 4117,
#  'wood': 7796,
#  'huge': 3602,
#  'difference': 2346,
#  'personally': 5301,
#  'towns': 7274,
#  'distance': 2423,
#  'boston': 1218,
#  'worst': 7814,
#  '600': 369,
#  '43': 316,
#  '1990': 161,
#  'mitsubishi': 4675,
#  'chicago': 1526,
#  'coverage': 2010,
#  'discount': 2393,
#  'miles': 4622,
#  'lived': 4320,
#  '41': 309,
#  '93': 445,
#  'sho': 6508,
#  '287': 247,
#  'month': 4720,
#  'thats': 7158,
#  'property': 5658,
#  '250': 224,
#  'glass': 3285,
#  '39': 295,
#  'seriously': 6443,
#  'ripped': 6151,
#  'listed': 4309,
#  '2k': 253,
#  'calling': 1362,
#  'dealers': 2147,
#  'places': 5376,
#  'changed': 1484,
#  'maintain': 4428,
#  'careful': 1405,
#  'voltage': 7621,
#  'signal': 6543,
#  'output': 5112,
#  'preferably': 5524,
#  'factor': 2903,
#  'resulting': 6087,
#  'fed': 2965,
#  'easily': 2563,
#  'card': 1400,
#  'circuits': 1565,
#  'simple': 6562,
#  'amplifier': 713,
#  'practice': 5500,
#  'sufficiently': 6942,
#  'nicely': 4892,
#  'degrees': 2211,
#  'accuracy': 522,
#  'exact': 2781,
#  'entry': 2710,
#  'parameter': 5184,
#  'terminal': 7128,
#  'configuration': 1813,
#  'loaded': 4328,
#  'boots': 1206,
#  'tcp': 7078,
#  'ip': 3930,
#  'background': 1001,
#  'unix': 7458,
#  'running': 6237,
#  'mit': 4672,
#  'x11r4': 7843,
#  'sun': 6961,
#  'window': 7755,
#  'ncd': 4835,
#  'manually': 4458,
#  'login': 4347,
#  'telnet': 7112,
#  'session': 6452,
#  'tried': 7343,
#  'failed': 2909,
#  'implementation': 3687,
#  'bogus': 1189,
#  'edit': 2584,
#  'matter': 4516,
#  'containing': 1884,
#  'manuals': 4459,
#  'worthless': 7816,
#  'orders': 5079,
#  'motto': 4756,
#  'captain': 1395,
#  'sabres': 6257,
#  'traded': 7286,
#  'leafs': 4209,
#  'wasn': 7681,
#  'rick': 6131,
#  'thomas': 7178,
#  'ed': 2580,
#  'speaking': 6703,
#  'torn': 7257,
#  'jersey': 3992,
#  'claimed': 1584,
#  'flyers': 3072,
#  'oh': 5015,
#  'yeah': 7869,
#  'gretzky': 3362,
#  'oilers': 5019,
#  'catalog': 1427,
#  'computing': 1778,
#  'tools': 7253,
#  'engineers': 2690,
#  'lists': 4314,
#  'hardware': 3444,
#  'packages': 5147,
#  'xt': 7855,
#  'ps': 5699,
#  'focus': 3076,
#  'pcs': 5254,
#  'presentation': 5539,
#  'copy': 1957,
#  'postal': 5474,
#  'mailing': 4423,
#  'write': 7828,
#  'tons': 7247,
#  'stuff': 6903,
#  'appears': 777,
#  'buyer': 1336,
#  'waste': 7682,
#  'ensure': 2699,
#  'continued': 1897,
#  'subscription': 6917,
#  'touch': 7267,
#  '550': 356,
#  'street': 6871,
#  'campbell': 1373,
#  'ca': 1343,
#  '408': 307,
#  'fax': 2954,
#  'toll': 7239,
#  'ordering': 5078,
#  'tech': 7090,
#  'box': 1233,
#  'upper': 7482,
#  'left': 4227,
#  'click': 1608,
#  'simplistic': 6565,
#  'font': 3087,
#  ...}

# %%
text = 'I was wondering if anyone out there could enlighten me on this car I saw'
x = vectorizer.transform([text])
type(x)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from tqdm import tqdm

def lda(X, numtop, a, b, n_iter=10):
    n_key = np.zeros((numtop, X.shape[1]))
    n_dk = np.zeros((X.shape[0], numtop))
    n_k = np.zeros(numtop)
    
    docs, words = X.nonzero()
    z = np.random.choice(numtop, len(docs))
    
    for doc, word, cur_z in zip(docs, words, z):
        n_dk[doc, cur_z] += 1
        n_key[cur_z, word] += 1
        n_k[cur_z] += 1
    
    for cur_iter in tqdm(range(n_iter)):
        for i in range(len(docs)):
            cur_word = words[i]
            cur_doc = docs[i]
            cur_topic = z[i]
            
            n_dk[cur_doc, cur_topic] -= 1
            n_key[cur_topic, cur_word] -= 1
            n_k[cur_topic] -= 1
            
            p = (n_dk[cur_doc, :] + a) * (n_key[:, cur_word] + b[cur_word]) / \
                (n_k + b.sum())
            z[i] = np.random.choice(np.arange(numtop), p=p / p.sum())
            
            n_dk[cur_doc, z[i]] += 1
            n_key[z[i], cur_word] += 1
            n_k[z[i]] += 1
    
    return z, n_key, n_dk, n_k

# %%
vectorizer.inverse_transform(x)
# Out:
# [array(['car', 'saw', 'wondering'], dtype='<U79')]

# %%
X_train = vectorizer.fit_transform(newsgroups_train.data)
X_train.shape
# Out:
# (11314, 7891)

# %%
X_train.nnz / np.prod(X_train.shape)
# Out:
# 0.0050781835332998635

# %%
numtop = 20
z, n_key, n_dk, n_k = lda(X_train,numtop, 1 * np.ones(numtop), 1 * np.ones(X_train.shape[1]), 60)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 60/60 [31:38<00:00, 27.95s/it]

# %%
top_words = np.argsort(n_key, axis=1)[:, :-11:-1]

for topic in range(20):
    doc = np.zeros((1, X_train.shape[1]))
    for word in top_words[topic]:
        doc[0, word] = 1
    print('Topic {}:\t{}'.format(topic, '\t'.join(vectorizer.inverse_transform(doc)[0])))
# Out:
# Topic 0:	bible	christ	christian	christians	church	faith	jesus	man	religion	word
# Topic 1:	banks	chastity	geb	gordon	intellect	pitt	shameful	skepticism	soon	surrender
# Topic 2:	feel	hand	interesting	knows	recall	sorry	thinking	wasn	wonder	wouldn
# Topic 3:	card	computer	disk	dos	mac	memory	monitor	pc	sale	video
# Topic 4:	cause	common	disease	effect	evidence	result	results	study	treatment	usually
# Topic 5:	article	current	david	haven	imagine	oh	posting	sort	sounds	student
# Topic 6:	bike	buy	car	cars	engine	miles	ride	road	speed	turn
# Topic 7:	chip	clipper	encryption	key	keys	law	phone	public	secure	security
# Topic 8:	1993	april	center	date	earth	nasa	national	research	space	university
# Topic 9:	buy	care	cost	deal	market	money	pay	price	sell	worth
# Topic 10:	control	country	crime	gun	guns	law	laws	public	rights	states
# Topic 11:	btw	couple	difference	guess	haven	news	nice	original	regards	unfortunately
# Topic 12:	anybody	article	bob	info	ok	reply	short	sorry	stuff	thank
# Topic 13:	advance	appreciated	current	hi	input	low	output	radio	small	type
# Topic 14:	armenians	children	history	jewish	jews	killed	land	population	turkish	war
# Topic 15:	game	games	hockey	league	play	players	season	team	teams	win
# Topic 16:	address	check	code	faq	message	net	posted	questions	users	version
# Topic 17:	application	file	files	ftp	graphics	hi	running	server	sun	window
# Topic 18:	came	days	home	later	left	saw	started	told	wanted	went
# Topic 19:	certainly	couple	deleted	guess	oh	reading	says	sorry	stuff	week

# %% [markdown]
# Топик 0: религия
# Топик 3: компьютеры
# Топик 4: медицина
# Топик 6: машины
# Топик 7: шифрование
# Топик 8: космос
# Топик 9: экономика
# Топик 10: политика
# Топик 14: история
# Топик 15: хоккей
# Топик 16: виндоус
# Топик 17: ос виндоус
#
# Почти все из этих топиков есть в списке тренировочных тем

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']
